# %%
# %matplotlib inline

import pandas as pd

datetimeidx = pd.date_range('8/23/2015', periods=5, freq='D')
volatile_tickers = [('one', np.array([1.1, 1.2, 1.3, 10, 1.1])),
                    ('two', np.array([0.9, 1.6, 2.1, 11, 1.4])),
                    ('three', np.array([0.8, 0.5, 3.1, 12, 1.5]))
                    ]
ticker_vol_aug_24 = [('one', 1.0),
                    ('two', 2.0),
                    ('three',  3.0),
                     ('four', 1.0),
                    ]

# %%
import matplotlib.dates as mdates

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.plot(datetimeidx, np.asarray(vol).transpose())
plt.title("Volatility Over Time")
plt.ylabel("Intraday Volatility")
plt.gcf().autofmt_xdate()

# %%
def top_10():
    """Returns the top ten ticker symbols by volatility.
    """
    sorted_by_vol = sorted(ticker_vol_aug_24, key=lambda x: x[1], reverse=True)
    ticker_symbols = zip(*sorted_by_vol[:10])[0]
    return ticker_symbols

# %%
top_10()
# Out:
# ('three', 'two', 'one', 'four')
